# %% [markdown]
# # WR Binary - Holdout SplitAccount: yuanssy | Config: R_wr_serenitatis.yaml | 东部4区训练 + 风暴洋验证

# %%
import osDATASET = "/kaggle/input/datasets/yuanssy/wrdata/wr_dataset"DATA_DIR = os.path.join(DATASET, "holdout")PRETRAIN_DIR = os.path.join(DATASET, "pretrain")

# %%
# Install all dependencies (run this cell first)!pip install rasterio segmentation-models-pytorch timm -q

# %%
# !rm -rf /kaggle/working/lunar-linear!git clone https://github.com/song110585-cpu/lunar-linear.git /kaggle/working/lunar-linear!cd /kaggle/working/lunar-linear && git checkout test-new-module

# %%
# Verify imports work before trainingimport sys; sys.path.insert(0, '/kaggle/working/lunar-linear/STDL-Net/models')from swinv2unet import Swin_LCSRB_DeformablePSP_FPNPANprint('Imports OK')

# %%
# !cd /kaggle/working/lunar-linear/STDL-Net && python scripts/train.py \    --config configs/R_wr_serenitatis.yaml \    --data-dir {DATA_DIR} \    --pretrain-dir {PRETRAIN_DIR}
